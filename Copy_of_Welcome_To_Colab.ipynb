# %% [markdown]
# <a href="https://colab.research.google.com/github/Idakwo-Matthew-James05/EXPLORATOTY-DATA-ANALYSIS/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# importing relevant librares

# %%
df= pd.read_csv("/content/sample_data/california_housing_train.csv")
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# importind dataset

# %% [markdown]
# knowing data types

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# viwing top 5 roles of dataset

# %%
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_house_value
# 0      1015.0       472.0             66900.0
# 1      1129.0       463.0             80100.0
# 2       333.0       117.0             85700.0
# 3       515.0       226.0             73400.0
# 4       624.0       262.0             65500.0

# %%
df=df.rename(columns={"total_rooms" : "matthew"})
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  matthew  total_bedrooms  \
# 0    -114.31     34.19                15.0   5612.0          1283.0
# 1    -114.47     34.40                19.0   7650.0          1901.0
# 2    -114.56     33.69                17.0    720.0           174.0
# 3    -114.57     33.64                14.0   1501.0           337.0
# 4    -114.57     33.57                20.0   1454.0           326.0
#
#    population  households  median_house_value
# 0      1015.0       472.0             66900.0
# 1      1129.0       463.0             80100.0
# 2       333.0       117.0             85700.0
# 3       515.0       226.0             73400.0
# 4       624.0       262.0             65500.0

# %%
df.shape
# Out:
# (17000, 8)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 8)

# %%
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  matthew  total_bedrooms  \
# 0    -114.31     34.19                15.0   5612.0          1283.0
# 1    -114.47     34.40                19.0   7650.0          1901.0
# 2    -114.56     33.69                17.0    720.0           174.0
# 3    -114.57     33.64                14.0   1501.0           337.0
# 4    -114.57     33.57                20.0   1454.0           326.0
# 5    -114.58     33.63                29.0   1387.0           236.0
# 6    -114.58     33.61                25.0   2907.0           680.0
# 7    -114.59     34.83                41.0    812.0           168.0
# 8    -114.59     33.61                34.0   4789.0          1175.0
# 9    -114.60     34.83                46.0   1497.0           309.0
#
#    population  households  median_house_value
# 0      1015.0       472.0             66900.0
# 1      1129.0       463.0             80100.0
# 2       333.0       117.0             85700.0
# ...

# %%
df.count()
# Out:
# longitude             17000
# latitude              17000
# housing_median_age    17000
# matthew               17000
# total_bedrooms        17000
# population            17000
# households            17000
# median_house_value    17000
# dtype: int64

# %%
df = df.drop_duplicates()
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  matthew  total_bedrooms  \
# 0    -114.31     34.19                15.0   5612.0          1283.0
# 1    -114.47     34.40                19.0   7650.0          1901.0
# 2    -114.56     33.69                17.0    720.0           174.0
# 3    -114.57     33.64                14.0   1501.0           337.0
# 4    -114.57     33.57                20.0   1454.0           326.0
#
#    population  households  median_house_value
# 0      1015.0       472.0             66900.0
# 1      1129.0       463.0             80100.0
# 2       333.0       117.0             85700.0
# 3       515.0       226.0             73400.0
# 4       624.0       262.0             65500.0

# %%
df.count()
# Out:
# longitude             17000
# latitude              17000
# housing_median_age    17000
# matthew               17000
# total_bedrooms        17000
# population            17000
# households            17000
# median_house_value    17000
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# matthew               0
# total_bedrooms        0
# population            0
# households            0
# median_house_value    0
# dtype: int64

# %%
sns.boxplot(x=df['latitude'])
# Out:
# <Axes: xlabel='latitude'>

# %%
sns.boxplot(x=df['matthew'])
# Out:
# <Axes: xlabel='matthew'>

# %%
sns.boxplot(x=df['households'])
# Out:
# <Axes: xlabel='households'>

# %%
sns.boxplot(x=df["longitude"])
# Out:
# <Axes: xlabel='longitude'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# longitude                  3.79
# latitude                   3.79
# housing_median_age        19.00
# matthew                 1689.25
# total_bedrooms           351.25
# population               931.00
# households               323.25
# median_house_value    145600.00
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (14639, 8)

# %%
df.head(10)
# Out:
#     longitude  latitude  housing_median_age  matthew  total_bedrooms  \
# 2     -114.56     33.69                17.0    720.0           174.0
# 3     -114.57     33.64                14.0   1501.0           337.0
# 4     -114.57     33.57                20.0   1454.0           326.0
# 5     -114.58     33.63                29.0   1387.0           236.0
# 6     -114.58     33.61                25.0   2907.0           680.0
# 7     -114.59     34.83                41.0    812.0           168.0
# 9     -114.60     34.83                46.0   1497.0           309.0
# 10    -114.60     33.62                16.0   3741.0           801.0
# 11    -114.60     33.60                21.0   1988.0           483.0
# 12    -114.61     34.84                48.0   1291.0           248.0
#
#     population  households  median_house_value
# 2        333.0       117.0             85700.0
# 3        515.0       226.0             73400.0
# 4        624.0       262.0             65500.0
# ...

# %%
df.longitude.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of population")
plt.ylabel('Number of households')
plt.xlabel('longitude');

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                     longitude  latitude  housing_median_age   matthew  \
# longitude            1.000000 -0.924407           -0.094729 -0.000727
# latitude            -0.924407  1.000000           -0.003927 -0.002162
# housing_median_age  -0.094729 -0.003927            1.000000 -0.295741
# matthew             -0.000727 -0.002162           -0.295741  1.000000
# total_bedrooms       0.036626 -0.051598           -0.223916  0.882423
# population           0.120968 -0.151111           -0.187707  0.765521
# households           0.035736 -0.073873           -0.194918  0.876617
# median_house_value  -0.037308 -0.158887            0.081723  0.194974
#
#                     total_bedrooms  population  households  median_house_value
# longitude                 0.036626    0.120968    0.035736           -0.037308
# latitude                 -0.051598   -0.151111   -0.073873           -0.158887
# housing_median_age       -0.223916   -0.187707   -0.194918            0.081723
# ...

# %% [markdown]
# checking correlation between latitude and population

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['latitude'], df['population'])
ax.set_xlabel('latitude')
ax.set_ylabel('Population')
plt.show()
