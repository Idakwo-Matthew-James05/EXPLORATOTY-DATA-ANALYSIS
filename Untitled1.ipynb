# %%
import pandas as pd

# %%
import pandas as pd

# Paste the copied path inside the quotes
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df = df.drop(['total_bedrooms' ], axis=1)
df.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.05     37.37                27.0       3885.0      1537.0
# 1    -118.30     34.26                43.0       1510.0       809.0
# 2    -117.81     33.78                27.0       3589.0      1484.0
# 3    -118.36     33.82                28.0         67.0        49.0
# 4    -119.67     36.33                19.0       1241.0       850.0
#
#    households  median_income  median_house_value
# 0       606.0         6.6085            344700.0
# 1       277.0         3.5990            176500.0
# 2       495.0         5.7934            270500.0
# 3        11.0         6.1359            330000.0
# 4       237.0         2.9375             81700.0

# %%
df.head(3)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.05     37.37                27.0       3885.0      1537.0
# 1    -118.30     34.26                43.0       1510.0       809.0
# 2    -117.81     33.78                27.0       3589.0      1484.0
#
#    households  median_income  median_house_value
# 0       606.0         6.6085            344700.0
# 1       277.0         3.5990            176500.0
# 2       495.0         5.7934            270500.0

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df= df.rename(columns={"median_income": "matthew"})
df.head(4)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  population  \
# 0    -122.05     37.37                27.0       3885.0      1537.0
# 1    -118.30     34.26                43.0       1510.0       809.0
# 2    -117.81     33.78                27.0       3589.0      1484.0
# 3    -118.36     33.82                28.0         67.0        49.0
#
#    households  matthew  median_house_value
# 0       606.0   6.6085            344700.0
# 1       277.0   3.5990            176500.0
# 2       495.0   5.7934            270500.0
# 3        11.0   6.1359            330000.0

# %%
df.shape
# Out:
# (3000, 8)
